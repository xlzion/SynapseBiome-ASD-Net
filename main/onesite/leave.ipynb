# %%
import h5py
import numpy as np

def get_basename(item):
    """获取组或数据集的基名称"""
    name = item.name
    if name == '/':
        return '/'
    return name.split('/')[-1]

def print_hdf5_structure(item, indent_level=0):
    """递归打印HDF5文件结构"""
    indent = '  ' * indent_level
    basename = get_basename(item)

    # 处理组
    if isinstance(item, h5py.Group):
        # 打印组名称
        if item.name == '/':
            print(f"{indent}Group: /")
        else:
            print(f"{indent}Group: {basename}")
        
        # 打印组的属性
        for attr_name in item.attrs:
            attr_value = item.attrs[attr_name]
            # 处理不同类型的属性值
            if isinstance(attr_value, np.ndarray):
                attr_str = f"ndarray{attr_value.shape} {attr_value.dtype}"
            elif isinstance(attr_value, bytes):
                attr_str = attr_value.decode()
            else:
                attr_str = str(attr_value)
            print(f"{indent}  Attribute: {attr_name}: {attr_str}")
        
        # 递归遍历子项
        for key in item:
            child = item[key]
            print_hdf5_structure(child, indent_level + 1)
    
    # 处理数据集
    elif isinstance(item, h5py.Dataset):
        # 打印数据集信息
        print(f"{indent}Dataset: {basename} (Shape: {item.shape}, Dtype: {item.dtype})")
        
        # 打印数据集的属性
        for attr_name in item.attrs:
            attr_value = item.attrs[attr_name]
            if isinstance(attr_value, np.ndarray):
                attr_str = f"ndarray{attr_value.shape} {attr_value.dtype}"
            elif isinstance(attr_value, bytes):
                attr_str = attr_value.decode()
            else:
                attr_str = str(attr_value)
            print(f"{indent}  Attribute: {attr_name}: {attr_str}")

# 示例用法
with h5py.File('/home/yangzongxian/xlz/ASD_GCN/main/data2/abide.hdf5', 'r') as f:
    print_hdf5_structure(f)
# Out:
# Group: /
#   Group: experiments
#     Group: aal_leavesiteout-CALTECH
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#     Group: aal_leavesiteout-CMU
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#     Group: aal_leavesiteout-KKI
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#     Group: aal_leavesiteout-LEUVEN
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#     Group: aal_leavesiteout-MAX_MUN
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#     Group: aal_leavesiteout-NYU
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 1
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 2
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 3
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 4
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 5
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#       Group: 6
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#       Group: 7
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#       Group: 8
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#       Group: 9
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#     Group: aal_leavesiteout-OHSU
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#     Group: aal_leavesiteout-OLIN
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#     Group: aal_leavesiteout-PITT
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#     Group: aal_leavesiteout-SBL
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#     Group: aal_leavesiteout-SDSU
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (36,), Dtype: |S12)
#         Dataset: train (Shape: (699,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#     Group: aal_leavesiteout-STANFORD
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (39,), Dtype: |S16)
#         Dataset: train (Shape: (697,), Dtype: |S16)
#         Dataset: valid (Shape: (149,), Dtype: |S16)
#     Group: aal_leavesiteout-TRINITY
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (47,), Dtype: |S15)
#         Dataset: train (Shape: (691,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#     Group: aal_leavesiteout-UCLA
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (98,), Dtype: |S14)
#         Dataset: train (Shape: (655,), Dtype: |S16)
#         Dataset: valid (Shape: (141,), Dtype: |S16)
#     Group: aal_leavesiteout-UM
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (140,), Dtype: |S12)
#         Dataset: train (Shape: (626,), Dtype: |S16)
#         Dataset: valid (Shape: (134,), Dtype: |S16)
#     Group: aal_leavesiteout-USM
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (71,), Dtype: |S11)
#         Dataset: train (Shape: (674,), Dtype: |S16)
#         Dataset: valid (Shape: (145,), Dtype: |S16)
#     Group: aal_leavesiteout-YALE
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#     Group: aal_whole
#       Attribute: derivative: aal
#       Group: 0
#         Dataset: test (Shape: (104,), Dtype: object)
#         Dataset: train (Shape: (623,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#       Group: 1
#         Dataset: test (Shape: (104,), Dtype: object)
#         Dataset: train (Shape: (623,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#       Group: 2
#         Dataset: test (Shape: (104,), Dtype: object)
#         Dataset: train (Shape: (623,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#       Group: 3
#         Dataset: test (Shape: (104,), Dtype: object)
#         Dataset: train (Shape: (623,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#       Group: 4
#         Dataset: test (Shape: (104,), Dtype: object)
#         Dataset: train (Shape: (623,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#       Group: 5
#         Dataset: test (Shape: (103,), Dtype: object)
#         Dataset: train (Shape: (624,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#       Group: 6
#         Dataset: test (Shape: (103,), Dtype: object)
#         Dataset: train (Shape: (624,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#       Group: 7
#         Dataset: test (Shape: (103,), Dtype: object)
#         Dataset: train (Shape: (624,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#       Group: 8
#         Dataset: test (Shape: (103,), Dtype: object)
#         Dataset: train (Shape: (624,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#       Group: 9
#         Dataset: test (Shape: (103,), Dtype: object)
#         Dataset: train (Shape: (624,), Dtype: object)
#         Dataset: valid (Shape: (308,), Dtype: object)
#     Group: cc200_leavesiteout-CALTECH
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (37,), Dtype: |S15)
#         Dataset: train (Shape: (698,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#     Group: cc200_leavesiteout-CMU
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (27,), Dtype: |S13)
#         Dataset: train (Shape: (705,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#     Group: cc200_leavesiteout-KKI
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (48,), Dtype: |S11)
#         Dataset: train (Shape: (690,), Dtype: |S16)
#         Dataset: valid (Shape: (148,), Dtype: |S16)
#     Group: cc200_leavesiteout-LEUVEN
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (63,), Dtype: |S16)
#         Dataset: train (Shape: (680,), Dtype: |S16)
#         Dataset: valid (Shape: (146,), Dtype: |S16)
#     Group: cc200_leavesiteout-MAX_MUN
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (52,), Dtype: |S16)
#         Dataset: train (Shape: (688,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#     Group: cc200_leavesiteout-NYU
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 1
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 2
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 3
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 4
#         Dataset: test (Shape: (18,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (52,), Dtype: object)
#       Group: 5
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#       Group: 6
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#       Group: 7
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#       Group: 8
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#       Group: 9
#         Dataset: test (Shape: (17,), Dtype: object)
#         Dataset: train (Shape: (105,), Dtype: object)
#         Dataset: valid (Shape: (53,), Dtype: object)
#     Group: cc200_leavesiteout-OHSU
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (26,), Dtype: |S12)
#         Dataset: train (Shape: (706,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#     Group: cc200_leavesiteout-OLIN
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (34,), Dtype: |S12)
#         Dataset: train (Shape: (700,), Dtype: |S16)
#         Dataset: valid (Shape: (150,), Dtype: |S16)
#     Group: cc200_leavesiteout-PITT
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 2
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 3
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 4
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 5
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 6
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 7
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 8
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#       Group: 9
#         Dataset: test (Shape: (56,), Dtype: |S12)
#         Dataset: train (Shape: (685,), Dtype: |S16)
#         Dataset: valid (Shape: (147,), Dtype: |S16)
#     Group: cc200_leavesiteout-SBL
#       Attribute: derivative: cc200
#       Group: 0
#         Dataset: test (Shape: (30,), Dtype: |S11)
#         Dataset: train (Shape: (703,), Dtype: |S16)
#         Dataset: valid (Shape: (151,), Dtype: |S16)
#       Group: 1
#         Dataset: test (Shape: (30,), Dtype: |S11)
# ...
#     Group: Yale_0050552
#       Attribute: id: Yale_0050552
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050553
#       Attribute: id: Yale_0050553
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050554
#       Attribute: id: Yale_0050554
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050555
#       Attribute: id: Yale_0050555
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050556
#       Attribute: id: Yale_0050556
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050557
#       Attribute: id: Yale_0050557
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050558
#       Attribute: id: Yale_0050558
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050559
#       Attribute: id: Yale_0050559
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050560
#       Attribute: id: Yale_0050560
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050561
#       Attribute: id: Yale_0050561
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050562
#       Attribute: id: Yale_0050562
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050563
#       Attribute: id: Yale_0050563
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050564
#       Attribute: id: Yale_0050564
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050565
#       Attribute: id: Yale_0050565
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050566
#       Attribute: id: Yale_0050566
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050567
#       Attribute: id: Yale_0050567
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050568
#       Attribute: id: Yale_0050568
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050569
#       Attribute: id: Yale_0050569
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050570
#       Attribute: id: Yale_0050570
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050571
#       Attribute: id: Yale_0050571
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050572
#       Attribute: id: Yale_0050572
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050573
#       Attribute: id: Yale_0050573
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050574
#       Attribute: id: Yale_0050574
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050575
#       Attribute: id: Yale_0050575
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050576
#       Attribute: id: Yale_0050576
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050577
#       Attribute: id: Yale_0050577
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050578
#       Attribute: id: Yale_0050578
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 1
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050601
#       Attribute: id: Yale_0050601
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050602
#       Attribute: id: Yale_0050602
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050603
#       Attribute: id: Yale_0050603
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050604
#       Attribute: id: Yale_0050604
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050605
#       Attribute: id: Yale_0050605
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050606
#       Attribute: id: Yale_0050606
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050607
#       Attribute: id: Yale_0050607
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050608
#       Attribute: id: Yale_0050608
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050609
#       Attribute: id: Yale_0050609
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050610
#       Attribute: id: Yale_0050610
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050611
#       Attribute: id: Yale_0050611
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050612
#       Attribute: id: Yale_0050612
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050613
#       Attribute: id: Yale_0050613
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050614
#       Attribute: id: Yale_0050614
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050615
#       Attribute: id: Yale_0050615
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050616
#       Attribute: id: Yale_0050616
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050617
#       Attribute: id: Yale_0050617
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050618
#       Attribute: id: Yale_0050618
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050619
#       Attribute: id: Yale_0050619
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050620
#       Attribute: id: Yale_0050620
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050621
#       Attribute: id: Yale_0050621
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050622
#       Attribute: id: Yale_0050622
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050623
#       Attribute: id: Yale_0050623
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050624
#       Attribute: id: Yale_0050624
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050625
#       Attribute: id: Yale_0050625
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050626
#       Attribute: id: Yale_0050626
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050627
#       Attribute: id: Yale_0050627
#       Attribute: sex: 2
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
#     Group: Yale_0050628
#       Attribute: id: Yale_0050628
#       Attribute: sex: 1
#       Attribute: site: YALE
#       Attribute: y: 0
#       Dataset: aal (Shape: (6670,), Dtype: float32)
#       Dataset: cc200 (Shape: (19900,), Dtype: float32)
#       Dataset: ez (Shape: (6670,), Dtype: float32)
